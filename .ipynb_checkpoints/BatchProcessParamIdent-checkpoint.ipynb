# %%
# !dir /d "Subjects"

# %%
# !dir /s /b "Main.any"

# %%
import fnmatch
filtered = fnmatch.filter("Main.any", '?StandingRef?')

# %%
from anypytools import AnyPyProcess

folderlist = ["Subjects"]
app = AnyPyProcess(num_processes = 2,timeout = 10800)
macrolist = [
    'load "main.any"',
    'operation Main.RunParameterIdentification',
    'run'
]

app.start_macro(macrolist, folderlist, search_subdirs= "S00[0-5]_StandingRef.Main.any");
app.start_macro(macrolist, folderlist, search_subdirs= "S026_StandingRef.Main.any");
app.start_macro(macrolist, folderlist, search_subdirs= "S03[0-9]_StandingRef.Main.any");
app.start_macro(macrolist, folderlist, search_subdirs= "S041_StandingRef.Main.any");
