# %%
# !dir /d "Subjects"

# %%
# !dir /s /b "Main.any"
# Out:
# C:\Users\menmrk\Documents\AnyBody.8.0.x\AMMR4-Beta-OncoEng\Application\MocapExamples\Plug-in-gait_MultiTrial_StandingRef - OncoEng Analysis\Subjects\S001\S001_ADLSit_000\Main.any
# C:\Users\menmrk\Documents\AnyBody.8.0.x\AMMR4-Beta-OncoEng\Application\MocapExamples\Plug-in-gait_MultiTrial_StandingRef - OncoEng Analysis\Subjects\S001\S001_ADLStand_000\Main.any
# C:\Users\menmrk\Documents\AnyBody.8.0.x\AMMR4-Beta-OncoEng\Application\MocapExamples\Plug-in-gait_MultiTrial_StandingRef - OncoEng Analysis\Subjects\S001\S001_BND_002\Main.any
# C:\Users\menmrk\Documents\AnyBody.8.0.x\AMMR4-Beta-OncoEng\Application\MocapExamples\Plug-in-gait_MultiTrial_StandingRef - OncoEng Analysis\Subjects\S001\S001_BND_003\Main.any
# C:\Users\menmrk\Documents\AnyBody.8.0.x\AMMR4-Beta-OncoEng\Application\MocapExamples\Plug-in-gait_MultiTrial_StandingRef - OncoEng Analysis\Subjects\S001\S001_BND_003_SLM\Main.any
# ...

# %%
import fnmatch
filtered = fnmatch.filter("Main.any", '?StandingRef?')

# %%
from anypytools import AnyPyProcess

folderlist = ["Subjects"]
app = AnyPyProcess(num_processes = 2,timeout = 10800)
macrolist = [
    'load "main.any"',
    'operation Main.RunParameterIdentification',
    'run'
]

app.start_macro(macrolist, folderlist, search_subdirs= "S003_StandingRef_020.Main.any");
app.start_macro(macrolist, folderlist, search_subdirs= "S007_StandingRef_021.Main.any");
app.start_macro(macrolist, folderlist, search_subdirs= "S010_StandingRef_027.Main.any");
app.start_macro(macrolist, folderlist, search_subdirs= "S012_StandingRef_017.Main.any");
app.start_macro(macrolist, folderlist, search_subdirs= "S014_StandingRef_010.Main.any");
app.start_macro(macrolist, folderlist, search_subdirs= "S015_StandingRef_028.Main.any");
app.start_macro(macrolist, folderlist, search_subdirs= "S016_StandingRef_011.Main.any");
app.start_macro(macrolist, folderlist, search_subdirs= "S017_StandingRef_009.Main.any");
app.start_macro(macrolist, folderlist, search_subdirs= "S018_StandingRef_023.Main.any");
app.start_macro(macrolist, folderlist, search_subdirs= "S019_StandingRef_008.Main.any");
app.start_macro(macrolist, folderlist, search_subdirs= "S021_StandingRef_023.Main.any");
app.start_macro(macrolist, folderlist, search_subdirs= "S022_StandingRef_020.Main.any");
app.start_macro(macrolist, folderlist, search_subdirs= "S023_StandingRef_021.Main.any");
app.start_macro(macrolist, folderlist, search_subdirs= "S025_StandingRef_023.Main.any");

# %%
from anypytools import AnyPyProcess

folderlist = ["Subjects"]
app = AnyPyProcess(num_processes = 2,timeout = 10800)
macrolist = [
    'load "main.any"',
    'operation Main.RunParameterIdentification',
    'run'
]

app.start_macro(macrolist, folderlist, search_subdirs= "S016_StandingRef_011.Main.any");
app.start_macro(macrolist, folderlist, search_subdirs= "S021_StandingRef_023.Main.any");
app.start_macro(macrolist, folderlist, search_subdirs= "S022_StandingRef_020.Main.any");
app.start_macro(macrolist, folderlist, search_subdirs= "S023_StandingRef_021.Main.any");
app.start_macro(macrolist, folderlist, search_subdirs= "S025_StandingRef_023.Main.any");

# %%
import os

# Path to your AnyScript file
markerprotocol_file = r"C:\Users\menmrk\Documents\AnyBody.8.0.x\AMMR4-Beta-OncoEng\Application\MocapExamples\Plug-in-gait_MultiTrial_StandingRef - OncoEng Analysis\MarkerProtocol.any"

# Keywords to comment out
keywords_to_comment = ["#define _L2"]

# Read and modify the file
with open(markerprotocol_file, 'r') as file:
    lines = file.readlines()

new_lines = []
for line in lines:
    if any(keyword in line for keyword in keywords_to_comment):
        # Comment out the line if it contains any of the keywords
        if not line.strip().startswith("//"):
            line = "// " + line
    new_lines.append(line)

# Write the modified content back
with open(markerprotocol_file, 'w') as file:
    file.writelines(new_lines)

# %%
from anypytools import AnyPyProcess

folderlist = ["Subjects"]
app = AnyPyProcess(num_processes = 2,timeout = 10800)
macrolist = [
    'load "main.any"',
    'operation Main.RunParameterIdentification',
    'run'
]

app.start_macro(macrolist, folderlist, search_subdirs= "S010_StandingRef_027.Main.any");
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# Completed: 1

# %%
import re

# Path to your AnyScript file
markerprotocol_file = r"C:\Users\menmrk\Documents\AnyBody.8.0.x\AMMR4-Beta-OncoEng\Application\MocapExamples\Plug-in-gait_MultiTrial_StandingRef - OncoEng Analysis\MarkerProtocol.any"

# Keywords to target for uncommenting
keywords_to_uncomment = ["#define _L2"]

# Read the file
with open(markerprotocol_file, 'r') as file:
    lines = file.readlines()

# Uncomment lines
new_lines = []
for line in lines:
    if line.strip().startswith("//") and any(keyword in line for keyword in keywords_to_uncomment):
        line = re.sub(r'^\s*//\s*', '', line)
    new_lines.append(line)

# Write back the modified file
with open(markerprotocol_file, 'w') as file:
    file.writelines(new_lines)

# %%
import os

# Path to your AnyScript file
markerprotocol_file = r"C:\Users\menmrk\Documents\AnyBody.8.0.x\AMMR4-Beta-OncoEng\Application\MocapExamples\Plug-in-gait_MultiTrial_StandingRef - OncoEng Analysis\MarkerProtocol.any"

# Keywords to comment out
keywords_to_comment = ["#define _L1"]

# Read and modify the file
with open(markerprotocol_file, 'r') as file:
    lines = file.readlines()

new_lines = []
for line in lines:
    if any(keyword in line for keyword in keywords_to_comment):
        # Comment out the line if it contains any of the keywords
        if not line.strip().startswith("//"):
            line = "// " + line
    new_lines.append(line)

# Write the modified content back
with open(markerprotocol_file, 'w') as file:
    file.writelines(new_lines)

# %%
from anypytools import AnyPyProcess

folderlist = ["Subjects"]
app = AnyPyProcess(num_processes = 2,timeout = 10800)
macrolist = [
    'load "main.any"',
    'operation Main.RunParameterIdentification',
    'run'
]

app.start_macro(macrolist, folderlist, search_subdirs= "S025_StandingRef_023.Main.any");
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# Completed: 1

# %%
import re

# Path to your AnyScript file
markerprotocol_file = r"C:\Users\menmrk\Documents\AnyBody.8.0.x\AMMR4-Beta-OncoEng\Application\MocapExamples\Plug-in-gait_MultiTrial_StandingRef - OncoEng Analysis\MarkerProtocol.any"

# Keywords to target for uncommenting
keywords_to_uncomment = ["#define _L1"]

# Read the file
with open(markerprotocol_file, 'r') as file:
    lines = file.readlines()

# Uncomment lines
new_lines = []
for line in lines:
    if line.strip().startswith("//") and any(keyword in line for keyword in keywords_to_uncomment):
        line = re.sub(r'^\s*//\s*', '', line)
    new_lines.append(line)

# Write back the modified file
with open(markerprotocol_file, 'w') as file:
    file.writelines(new_lines)

# %%
from anypytools import AnyPyProcess

folderlist = ["Subjects"]
app = AnyPyProcess(num_processes = 2,timeout = 10800)
macrolist = [
    'load "main.any"',
    'operation Main.RunParameterIdentification',
    'run'
]

app.start_macro(macrolist, folderlist, search_subdirs= "S016_StandingRef_011.Main.any");
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# Completed: 1

# %%
from anypytools import AnyPyProcess

folderlist = ["Subjects"]
app = AnyPyProcess(num_processes = 2,timeout = 10800)
macrolist = [
    'load "main.any"',
    'operation Main.RunParameterIdentification',
    'run'
]

app.start_macro(macrolist, folderlist, search_subdirs= "S014_StandingRef_005_1F.Main.any");
app.start_macro(macrolist, folderlist, search_subdirs= "S014_StandingRef_022_10F.Main.any");
app.start_macro(macrolist, folderlist, search_subdirs= "S015_StandingRef_006_1F.Main.any");
app.start_macro(macrolist, folderlist, search_subdirs= "S015_StandingRef_026_10F.Main.any");
app.start_macro(macrolist, folderlist, search_subdirs= "S016_StandingRef_002_1F.Main.any");
app.start_macro(macrolist, folderlist, search_subdirs= "S016_StandingRef_020_10F.Main.any");
app.start_macro(macrolist, folderlist, search_subdirs= "S021_StandingRef_004_1F.Main.any");
app.start_macro(macrolist, folderlist, search_subdirs= "S021_StandingRef_020_10F.Main.any");
app.start_macro(macrolist, folderlist, search_subdirs= "S023_StandingRef_004_1F.Main.any");
app.start_macro(macrolist, folderlist, search_subdirs= "S023_StandingRef_019_10F.Main.any");
app.start_macro(macrolist, folderlist, search_subdirs= "S024_StandingRef_004_1F.Main.any");
app.start_macro(macrolist, folderlist, search_subdirs= "S024_StandingRef_020_10F.Main.any");
